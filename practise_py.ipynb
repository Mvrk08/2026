# %% [markdown]
# <a href="https://colab.research.google.com/github/Mvrk08/2026/blob/main/practise_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_even_odd(num):
    if num % 2 ==0 :
     print("even no detected")

    else:
     print("odd no detected")

number = int(input("plz enter your no :  "))
check_even_odd(number)


#####

def area_of_circle(radius) :
   area =  3.14* radius * radius
   return area

value = int (input("enter the radius :"))
print(area_of_circle(value))

###########

def area_trinagle(side):
  area = 3*side
  return area

value = int (input("enter side  plz"))
print(area_trinagle(value))


 # Take 2 numbers as input and print the largest number.


def two_nos(num1 ,num2):
 value =0

 if num1 > num2:
        value = num1
 else:
        value = num2
        return value

a = int(input("enter no 1 :"))
b= int(input("enter no 2 :"))

print("greatest no among these is ",two_nos(a,b))





# Input currency in rupees and output in USD.

def curency_conversion(rs) :
   usd = rs/94.65
   return usd

amount =float (input("enter the inr amount"))
print("amount in usd ",curency_conversion(amount) )




# defining even no of days in a month


def even_no_of_days(days):
   num =0
   for num in range (1,31):
     num%2==0
     return num

   days = int("no od days kunal can go out" ,even_no_of_days(num))

# %%
#A person is eligible to vote if his/her age is greater than or equal to 18. Define a method to find out if he/she is eligible to vote



def age_check(age):


  if age >=18:
    print("you are  my nigga man ")
  else  :
    print("shit nigga you arnt gangsta")

    age= int(input("tell ur age nigga" ,))

    age_check(age)





def age_check(age):
    if age >= 18:
        print("you are my nigga man")
    else:
        print("shit nigga you arnt gangsta")


age = int(input("Tell your age: "))
age_check(age)
# Out:
# Tell your age: 32
# you are my nigga man
